# %% [markdown]
# # CART-POLE GYM ENVIRONMENT

# %% [markdown]
# Our aim is to devise RL algorithms to try and solve the "Cart-Pole" environment provided in the Open-AI gym. In this environment, a pole is attached to a cart which can move left or right. Our goal is to apply forces to the cart so as to keep it upright. An episode runs a maximum for 500 time-steps, hence if the pole stays upright for 500 time-steps, the episode is considered solved. The reward for each time-step is 1.

# %% [markdown]
# The action space for this environment is a ndarray with shape (1,) which can take values {0,1} indicating the direction of the fixed force the cart is pushed with. The observation space is a ndarray with shape (4,) which contains the following values:
# | Num | Observation | Min | Max |
# |-----------------|-----------------| -----|-----|
# | 0  | Cart Position  | -4.8 | 4.8 |
# | 1  | Cart Velocity  | -Inf | Inf |
# | 2  | Pole Angle     | -24 deg | 24 deg |
# | 3  | Pole Angular Velocity  | -Inf | Inf |
#
# Also, the episode terminates if the cart position leaves the range [-2.4, 2.4] or the pole angle leaves the range [-12 deg, 12 deg] and the pole angle is returned in radians.

# %% [markdown]
# Now, the State Space is continous, hence we cannot just use a lookup table to store our Q-values. There are two ways we can counter this, one is we use a function approximator with some parameters to approximate our Q-values. Another way is to discretise the state space, as to break it into a discrete space rather than being continous.

# %% [markdown]
# To discretize the state space we will split each observation into some n equal parts and assign each interval to its lower bound. Now for obs number 0 and 2 we can discretize in a way that if the values are outside their non terminal range, we just put all of those into one interval rather than splitting them but as of now we aren't doing that, maybe we'll try later to see if it optimises our space much. (As in our original implementation a lot of the states won't ever be reached as the episode terminates before reaching them). For observation 1 and 3, they go from -INF to +INF, hence we can't just split it into some n intervals and get a finite state space. For that what we did was we ran the environment many times by hand to get an idea of the range of values the velocity and angular velocity stay in before the episode terminates because the velocity or angular velocity we just to large enough to be able to correct.

# %% [markdown]
# Using this code, we did some experimentation.

# %%
import gymnasium as gym

env = gym.make("CartPole-v1" , render_mode="rgb_array")
env.reset()
while True:
    action = int(input("Action: "))
    if action in (0, 1):
        x = env.step(action)
        print(f"v:{x[0][1]} , w:{x[0][3]}")
        env.render()

# %% [markdown]
# From this we got to the conclusion that velocity takes values between -4 and 4 and angular velocity stays between -4 and 4 at max. Also if the values go outside this interval, we equate them to these bounds.

# %% [markdown]
# Doing some pretty basic mathematics we see that we can implementing this by mapping our observation x to $$round(\frac{x-a}{b-a} \times n)$$ where n is the "granularity constant" and a and b are the lower and upper bounds of x respectively.

# %% [markdown]
# Now coming to the RL algorithm to be used, we see all episodes are guaranteed to be terminated, hence we can use any either forward view or backward view algorithm. Here we'll be implementing backward view SARSA($\lambda$) with Eligibility Traces.

# %% [markdown]
# First we import the required modules we'll be using.

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Now we'll define some constants which we'll be using throughout such as learning rate, discount factor etc.

# %%
granularity_0 = 8
granularity_1 = 8
granularity_2 = 32
granularity_3 = 16

EPSILON_INIT = 1
EPSILON_DECAY = 0.9994
EPSILON_MIN = 0.05
EPSILON = EPSILON_INIT

DISCOUNT_FACTOR = 0.9

LEARNING_RATE = 0.9
LEARNING_RATE_DECAY = 0.99999

LAMBDA = 0.4

# %% [markdown]
# Also initialise some other variables and our q tables

# %%
Q = np.zeros(( granularity_0 , granularity_1 , granularity_2 , granularity_3  , 2))
n = 30000
mean_width = 100
reward_list = np.zeros(n+1)
average_reward_list = np.zeros(n+1)
mean_reward_list = np.zeros(n-mean_width+1)
ep_count = 0

# %%
def choose_action(state):
    global EPSILON
    EPSILON = max(EPSILON_MIN , EPSILON * EPSILON_DECAY)
    if(np.random.random() < EPSILON):
        return int(env.action_space.sample())
    else:
        return np.argmax(Q[int(state[0]) , int(state[1]), int(state[2]) , int(state[3]) , :])

# %%
def discretize_state(state):
    state[0] = int(((state[0] + 4.8) / (9.6)) * granularity_0 )
    state[1] = int(((state[1] + 4.0) / (8.0)) * granularity_1 )
    state[2] = int(((state[2] + 0.42) / (0.84)) * granularity_2 )
    state[3] = int(((state[3] + 4.0) / (8.0)) * granularity_3 )
    return (state)

# %% [markdown]
# The choose_action function implements our epsilon-greedy algorithm and the discretize_states function discretizes our state space based on the corresponding granularity constant.

# %%
env = gym.make("CartPole-v1" , render_mode="rgb_array")

while(n):
    n -= 1
    ep_count += 1
    E = np.zeros(( granularity_0 , granularity_1 , granularity_2 , granularity_3  , 2))
    state_prev = env.reset()[0]
    state_prev = discretize_state(state_prev)
    action_prev = env.action_space.sample()
    total_reward = 0
    while(True):
        state, reward, done, truncated, info = env.step(action_prev)
        total_reward += reward
        state = discretize_state(state)
        action = choose_action(state)
        Td_error = reward + (DISCOUNT_FACTOR * Q[int(state[0]) , int(state[1]), int(state[2]) , int(state[3]) , action]) - Q[int(state_prev[0]) , int(state_prev[1]), int(state_prev[2]) , int(state_prev[3]) , action_prev]
        E[int(state_prev[0]) , int(state_prev[1]), int(state_prev[2]) , int(state_prev[3]) , action_prev] += 1
        Q += LEARNING_RATE * Td_error * E
        E *= (DISCOUNT_FACTOR * LAMBDA)
        state_prev = state
        action_prev = action
        if done:
            break
    # LEARNING_RATE = max(0.1 , LEARNING_RATE * LEARNING_RATE_DECAY)
    reward_list[ep_count] = total_reward
    average_reward_list[ep_count] = reward_list[:ep_count].mean()
    if ep_count > mean_width:
        mean_reward_list[ep_count-mean_width] = reward_list[ep_count-mean_width:ep_count].mean()
    print(f"total_reward : {total_reward} , episode : {ep_count}")
# Out:
# total_reward : 11.0 , episode : 1
# total_reward : 17.0 , episode : 2
# total_reward : 32.0 , episode : 3
# total_reward : 29.0 , episode : 4
# total_reward : 15.0 , episode : 5
# total_reward : 25.0 , episode : 6
# total_reward : 24.0 , episode : 7
# total_reward : 17.0 , episode : 8
# total_reward : 14.0 , episode : 9
# total_reward : 28.0 , episode : 10
# total_reward : 16.0 , episode : 11
# total_reward : 31.0 , episode : 12
# total_reward : 16.0 , episode : 13
# total_reward : 12.0 , episode : 14
# total_reward : 22.0 , episode : 15
# total_reward : 10.0 , episode : 16
# total_reward : 20.0 , episode : 17
# total_reward : 35.0 , episode : 18
# total_reward : 36.0 , episode : 19
# total_reward : 29.0 , episode : 20
# total_reward : 11.0 , episode : 21
# total_reward : 11.0 , episode : 22
# total_reward : 29.0 , episode : 23
# total_reward : 28.0 , episode : 24
# total_reward : 19.0 , episode : 25
# total_reward : 47.0 , episode : 26
# total_reward : 12.0 , episode : 27
# total_reward : 11.0 , episode : 28
# total_reward : 16.0 , episode : 29
# total_reward : 15.0 , episode : 30
# total_reward : 32.0 , episode : 31
# total_reward : 16.0 , episode : 32
# total_reward : 24.0 , episode : 33
# total_reward : 25.0 , episode : 34
# total_reward : 40.0 , episode : 35
# total_reward : 11.0 , episode : 36
# total_reward : 42.0 , episode : 37
# total_reward : 75.0 , episode : 38
# total_reward : 21.0 , episode : 39
# total_reward : 21.0 , episode : 40
# total_reward : 53.0 , episode : 41
# total_reward : 18.0 , episode : 42
# total_reward : 31.0 , episode : 43
# total_reward : 15.0 , episode : 44
# total_reward : 14.0 , episode : 45
# total_reward : 16.0 , episode : 46
# total_reward : 36.0 , episode : 47
# total_reward : 15.0 , episode : 48
# total_reward : 46.0 , episode : 49
# total_reward : 21.0 , episode : 50
# total_reward : 21.0 , episode : 51
# total_reward : 45.0 , episode : 52
# total_reward : 34.0 , episode : 53
# total_reward : 46.0 , episode : 54
# total_reward : 80.0 , episode : 55
# total_reward : 77.0 , episode : 56
# total_reward : 54.0 , episode : 57
# total_reward : 26.0 , episode : 58
# total_reward : 20.0 , episode : 59
# total_reward : 16.0 , episode : 60
# total_reward : 17.0 , episode : 61
# total_reward : 43.0 , episode : 62
# total_reward : 24.0 , episode : 63
# total_reward : 14.0 , episode : 64
# total_reward : 42.0 , episode : 65
# total_reward : 35.0 , episode : 66
# total_reward : 61.0 , episode : 67
# total_reward : 50.0 , episode : 68
# total_reward : 21.0 , episode : 69
# total_reward : 17.0 , episode : 70
# total_reward : 15.0 , episode : 71
# total_reward : 31.0 , episode : 72
# total_reward : 31.0 , episode : 73
# total_reward : 45.0 , episode : 74
# total_reward : 21.0 , episode : 75
# total_reward : 79.0 , episode : 76
# total_reward : 40.0 , episode : 77
# total_reward : 22.0 , episode : 78
# total_reward : 21.0 , episode : 79
# total_reward : 52.0 , episode : 80
# total_reward : 34.0 , episode : 81
# total_reward : 49.0 , episode : 82
# total_reward : 36.0 , episode : 83
# total_reward : 49.0 , episode : 84
# total_reward : 41.0 , episode : 85
# total_reward : 53.0 , episode : 86
# total_reward : 42.0 , episode : 87
# total_reward : 133.0 , episode : 88
# total_reward : 264.0 , episode : 89
# total_reward : 51.0 , episode : 90
# total_reward : 22.0 , episode : 91
# total_reward : 17.0 , episode : 92
# total_reward : 39.0 , episode : 93
# total_reward : 14.0 , episode : 94
# total_reward : 136.0 , episode : 95
# total_reward : 18.0 , episode : 96
# total_reward : 50.0 , episode : 97
# total_reward : 46.0 , episode : 98
# total_reward : 61.0 , episode : 99
# total_reward : 76.0 , episode : 100
# total_reward : 38.0 , episode : 101
# total_reward : 13.0 , episode : 102
# total_reward : 31.0 , episode : 103
# total_reward : 46.0 , episode : 104
# total_reward : 47.0 , episode : 105
# total_reward : 21.0 , episode : 106
# total_reward : 28.0 , episode : 107
# total_reward : 47.0 , episode : 449
# total_reward : 91.0 , episode : 450
# total_reward : 38.0 , episode : 451
# total_reward : 92.0 , episode : 452
# total_reward : 45.0 , episode : 453
# total_reward : 56.0 , episode : 454
# total_reward : 93.0 , episode : 455
# total_reward : 81.0 , episode : 456
# total_reward : 133.0 , episode : 457
# total_reward : 93.0 , episode : 458
# total_reward : 57.0 , episode : 459
# total_reward : 49.0 , episode : 460
# total_reward : 70.0 , episode : 461
# total_reward : 215.0 , episode : 462
# total_reward : 101.0 , episode : 463
# total_reward : 35.0 , episode : 464
# total_reward : 145.0 , episode : 465
# total_reward : 87.0 , episode : 466
# total_reward : 64.0 , episode : 467
# total_reward : 41.0 , episode : 468
# total_reward : 44.0 , episode : 469
# total_reward : 60.0 , episode : 470
# total_reward : 29.0 , episode : 471
# total_reward : 111.0 , episode : 472
# total_reward : 64.0 , episode : 473
# total_reward : 53.0 , episode : 474
# total_reward : 74.0 , episode : 475
# total_reward : 35.0 , episode : 476
# total_reward : 137.0 , episode : 477
# total_reward : 68.0 , episode : 478
# total_reward : 171.0 , episode : 479
# total_reward : 94.0 , episode : 480
# total_reward : 256.0 , episode : 481
# total_reward : 55.0 , episode : 482
# total_reward : 103.0 , episode : 483
# total_reward : 77.0 , episode : 484
# total_reward : 59.0 , episode : 485
# total_reward : 56.0 , episode : 486
# total_reward : 95.0 , episode : 487
# total_reward : 111.0 , episode : 488
# total_reward : 60.0 , episode : 489
# total_reward : 95.0 , episode : 490
# total_reward : 96.0 , episode : 491
# total_reward : 58.0 , episode : 492
# total_reward : 24.0 , episode : 493
# total_reward : 34.0 , episode : 494
# total_reward : 156.0 , episode : 495
# total_reward : 70.0 , episode : 496
# total_reward : 36.0 , episode : 497
# total_reward : 24.0 , episode : 498
# total_reward : 63.0 , episode : 499
# total_reward : 48.0 , episode : 500
# total_reward : 57.0 , episode : 501
# total_reward : 45.0 , episode : 502
# total_reward : 214.0 , episode : 503
# total_reward : 56.0 , episode : 504
# total_reward : 39.0 , episode : 505
# total_reward : 57.0 , episode : 506
# total_reward : 175.0 , episode : 507
# total_reward : 17.0 , episode : 508
# total_reward : 29.0 , episode : 509
# total_reward : 87.0 , episode : 510
# total_reward : 41.0 , episode : 511
# total_reward : 49.0 , episode : 512
# total_reward : 42.0 , episode : 513
# total_reward : 22.0 , episode : 514
# total_reward : 28.0 , episode : 515
# total_reward : 19.0 , episode : 516
# total_reward : 42.0 , episode : 517
# total_reward : 121.0 , episode : 518
# total_reward : 123.0 , episode : 519
# total_reward : 167.0 , episode : 520
# total_reward : 64.0 , episode : 521
# total_reward : 63.0 , episode : 522
# total_reward : 83.0 , episode : 523
# total_reward : 101.0 , episode : 524
# total_reward : 101.0 , episode : 525
# total_reward : 238.0 , episode : 526
# total_reward : 103.0 , episode : 527
# total_reward : 32.0 , episode : 528
# total_reward : 34.0 , episode : 529
# total_reward : 38.0 , episode : 530
# total_reward : 37.0 , episode : 531
# total_reward : 82.0 , episode : 532
# total_reward : 30.0 , episode : 533
# total_reward : 143.0 , episode : 29879
# total_reward : 187.0 , episode : 29880
# total_reward : 120.0 , episode : 29881
# total_reward : 116.0 , episode : 29882
# total_reward : 140.0 , episode : 29883
# total_reward : 178.0 , episode : 29884
# total_reward : 932.0 , episode : 29885
# total_reward : 220.0 , episode : 29886
# total_reward : 253.0 , episode : 29887
# total_reward : 186.0 , episode : 29888
# total_reward : 135.0 , episode : 29889
# total_reward : 580.0 , episode : 29890
# total_reward : 128.0 , episode : 29891
# total_reward : 140.0 , episode : 29892
# total_reward : 84.0 , episode : 29893
# total_reward : 230.0 , episode : 29894
# total_reward : 115.0 , episode : 29895
# total_reward : 120.0 , episode : 29896
# total_reward : 103.0 , episode : 29897
# total_reward : 156.0 , episode : 29898
# total_reward : 15.0 , episode : 29899
# total_reward : 159.0 , episode : 29900
# total_reward : 276.0 , episode : 29901
# total_reward : 129.0 , episode : 29902
# total_reward : 375.0 , episode : 29903
# total_reward : 573.0 , episode : 29904
# total_reward : 294.0 , episode : 29905
# total_reward : 44.0 , episode : 29906
# total_reward : 283.0 , episode : 29907
# total_reward : 389.0 , episode : 29908
# total_reward : 761.0 , episode : 29909
# total_reward : 118.0 , episode : 29910
# total_reward : 289.0 , episode : 29911
# total_reward : 320.0 , episode : 29912
# total_reward : 469.0 , episode : 29913
# total_reward : 270.0 , episode : 29914
# total_reward : 117.0 , episode : 29915
# total_reward : 226.0 , episode : 29916
# total_reward : 644.0 , episode : 29917
# total_reward : 767.0 , episode : 29918
# total_reward : 1276.0 , episode : 29919
# total_reward : 385.0 , episode : 29920
# total_reward : 211.0 , episode : 29921
# total_reward : 158.0 , episode : 29922
# total_reward : 165.0 , episode : 29923
# total_reward : 198.0 , episode : 29924
# total_reward : 190.0 , episode : 29925
# total_reward : 367.0 , episode : 29926
# total_reward : 374.0 , episode : 29927
# total_reward : 220.0 , episode : 29928
# total_reward : 405.0 , episode : 29929
# total_reward : 265.0 , episode : 29930
# total_reward : 401.0 , episode : 29931
# total_reward : 119.0 , episode : 29932
# total_reward : 335.0 , episode : 29933
# total_reward : 389.0 , episode : 29934
# total_reward : 142.0 , episode : 29935
# total_reward : 206.0 , episode : 29936
# total_reward : 250.0 , episode : 29937
# total_reward : 204.0 , episode : 29938
# total_reward : 112.0 , episode : 29939
# total_reward : 134.0 , episode : 29940
# total_reward : 245.0 , episode : 29941
# total_reward : 116.0 , episode : 29942
# total_reward : 554.0 , episode : 29943
# total_reward : 221.0 , episode : 29944
# total_reward : 21.0 , episode : 29945
# total_reward : 133.0 , episode : 29946
# total_reward : 119.0 , episode : 29947
# total_reward : 129.0 , episode : 29948
# total_reward : 99.0 , episode : 29949
# total_reward : 149.0 , episode : 29950
# total_reward : 369.0 , episode : 29951
# total_reward : 369.0 , episode : 29952
# total_reward : 84.0 , episode : 29953
# total_reward : 112.0 , episode : 29954
# total_reward : 85.0 , episode : 29955
# total_reward : 215.0 , episode : 29956
# total_reward : 175.0 , episode : 29957
# total_reward : 187.0 , episode : 29958
# total_reward : 115.0 , episode : 29959
# total_reward : 193.0 , episode : 29960
# total_reward : 114.0 , episode : 29961
# total_reward : 222.0 , episode : 29962
# total_reward : 133.0 , episode : 29963
# total_reward : 138.0 , episode : 29964
# total_reward : 187.0 , episode : 29965
# total_reward : 22.0 , episode : 29966
# total_reward : 112.0 , episode : 29967
# total_reward : 134.0 , episode : 29968
# total_reward : 208.0 , episode : 29969
# total_reward : 126.0 , episode : 29970
# total_reward : 197.0 , episode : 29971
# total_reward : 140.0 , episode : 29972
# total_reward : 130.0 , episode : 29973
# total_reward : 270.0 , episode : 29974
# total_reward : 130.0 , episode : 29975
# total_reward : 176.0 , episode : 29976
# total_reward : 13.0 , episode : 29977
# total_reward : 537.0 , episode : 29978
# total_reward : 369.0 , episode : 29979
# total_reward : 220.0 , episode : 29980
# total_reward : 110.0 , episode : 29981
# total_reward : 246.0 , episode : 29982
# total_reward : 168.0 , episode : 29983
# total_reward : 307.0 , episode : 29984
# total_reward : 135.0 , episode : 29985
# total_reward : 197.0 , episode : 29986
# total_reward : 99.0 , episode : 29987
# total_reward : 138.0 , episode : 29988
# total_reward : 27.0 , episode : 29989
# total_reward : 337.0 , episode : 29990
# total_reward : 183.0 , episode : 29991
# total_reward : 369.0 , episode : 29992
# total_reward : 395.0 , episode : 29993
# total_reward : 128.0 , episode : 29994
# total_reward : 184.0 , episode : 29995
# total_reward : 403.0 , episode : 29996
# total_reward : 117.0 , episode : 29997
# total_reward : 22.0 , episode : 29998
# total_reward : 249.0 , episode : 29999
# total_reward : 111.0 , episode : 30000

# %%
plt.plot(average_reward_list)
plt.text(20000,125,"[8,8,32,16],[0.4]")
plt.show()

# %%
plt.plot(mean_reward_list)
plt.text(20000,125,"[8,8,32,16],[0.4]")
plt.show()

# %%
mean_reward_list2 = np.zeros(ep_count - 1000 + 1)
for i in range(1000,ep_count):
    mean_reward_list2[i-1000] = reward_list[i-1000:i].mean()

# %%
plt.plot(mean_reward_list2[:ep_count-1000])
plt.text(20000,125,"[8,8,32,16],[0.4]")
plt.show()

# %% [markdown]
# The first graph we have plotted is the average reward from episode 1 till n. The second graph is the mean reward of the last 100 episodes and the third graph plots the mean for the last 1000 episodess. Its pretty evident that around 12000-13000, the progress has stagnated and we're getting an average reward of around 200-220.

# %% [markdown]
# $\textbf{So now that our algorithm "works", let's try and tweak some of our hyperparameters and try to understand their significance and effects.}$

# %% [markdown]
# First let's see how changing granularity constants affect our algorithm. Let's increase our granularity by 4 times making our state space finer and see what that does. As now we take up a lot more space and each episode will run slower let's also reduce the no. of episodes else it'll take too much time to end. Now we'll reuse the next blocks to get results.

# %%
granularity_0 = 8
granularity_1 = 8
granularity_2 = 32
granularity_3 = 16

EPSILON_INIT = 1
EPSILON_DECAY = 0.9994
EPSILON_MIN = 0.05
EPSILON = EPSILON_INIT

DISCOUNT_FACTOR = 0.9

LEARNING_RATE = 0.9
LEARNING_RATE_DECAY = 0.99999

LAMBDA = 0.0

Q = np.zeros(( granularity_0 , granularity_1 , granularity_2 , granularity_3  , 2))
n = 30000
mean_width = 100
reward_list = np.zeros(n+1)
average_reward_list = np.zeros(n+1)
mean_reward_list = np.zeros(n-mean_width+1)
ep_count = 0

# %%
ml = []
arl = []
for LAMBDA in [0.0, 0.1,0.4,0.6,0.8,1.0]:
    Q = np.zeros(( granularity_0 , granularity_1 , granularity_2 , granularity_3  , 2))
    n = 12500
    mean_width = 100
    reward_list = np.zeros(n+1)
    average_reward_list = np.zeros(n+1)
    mean_reward_list = np.zeros(n-mean_width+1)
    ep_count = 0
    while(n):
        n -= 1
        ep_count += 1
        E = np.zeros(( granularity_0 , granularity_1 , granularity_2 , granularity_3  , 2))
        state_prev = env.reset()[0]
        state_prev = discretize_state(state_prev)
        action_prev = env.action_space.sample()
        total_reward = 0
        while(True):
            state, reward, done, truncated, info = env.step(action_prev)
            total_reward += reward
            state = discretize_state(state)
            action = choose_action(state)
            Td_error = reward + (DISCOUNT_FACTOR * Q[int(state[0]) , int(state[1]), int(state[2]) , int(state[3]) , action]) - Q[int(state_prev[0]) , int(state_prev[1]), int(state_prev[2]) , int(state_prev[3]) , action_prev]
            E[int(state_prev[0]) , int(state_prev[1]), int(state_prev[2]) , int(state_prev[3]) , action_prev] += 1
            Q += LEARNING_RATE * Td_error * E
            E *= (DISCOUNT_FACTOR * LAMBDA)
            state_prev = state
            action_prev = action
            if done:
                break
        # LEARNING_RATE = max(0.1 , LEARNING_RATE * LEARNING_RATE_DECAY)
        reward_list[ep_count] = total_reward
        average_reward_list[ep_count] = reward_list[:ep_count].mean()
        if ep_count > mean_width:
            mean_reward_list[ep_count-mean_width] = reward_list[ep_count-mean_width:ep_count].mean()
        # print(f"total_reward : {total_reward} , episode : {ep_count}")
    print(f"{LAMBDA} done")
    ml.append(mean_reward_list)
    arl.append(average_reward_list)
# Out:
# 0.0 done
# 0.1 done
# 0.4 done
# 0.6 done
# 0.8 done
# 1.0 done

# %% [markdown]
# Ran it for granularity [32,32,32,32] and it just takes too much time to run each episode without any significant increase in rewards early on compared to [8,8,32,16]. Let's try lower granularity of [5,5,8,5].

# %%
plt.plot(average_reward_list)
plt.text(20000,25,"[5,5,8,5],[0.4]")
plt.show()

# %%
plt.plot(mean_reward_list)
plt.text(20000,10,"[5,5,8,5],[0.4]")
plt.show()

# %% [markdown]
# We see with [5,5,8,5] the algorithm converges around just 35 reward. The reason we think this might be because the state space is so coarse that its not able to capture enough detail of the observation space and hence within an interval the actions lead to the terminal state.

# %% [markdown]
# I think this is enough to get a good approximation of the granularity that is optimal.

# %% [markdown]
# Now let's try to see what lambda is best for our model. We know lambda = 0 corresponds to TD(0) learning and lambda = 1 corresponds to MC learning.

# %%
LAMBDA = [0.0,0.1,0.4,0.6,0.8,1.0]
for i in range(6):
    plt.subplot(2,1,1)
    plt.plot(ml[i] , label = f"{LAMBDA[i]}")
    plt.legend()
    plt.subplot(2,1,2)
    plt.plot(arl[i] , label = f"{LAMBDA[i]}")
    plt.legend()
plt.show()

# %% [markdown]
# ## We can see that the optimal lambda is around 0.4 to 0.5.
